# %% [markdown]
# # Importing important libraries

# %%
import pandas as pd  # Importing pandas library for data manipulation and analysis.
import numpy as np  # Importing numpy library for numerical computations and array operations.
import matplotlib.pyplot as plt  # Importing matplotlib library for data visualization and plotting.

# %% [markdown]
# # Write a python program to load data into pandas DataFrame

# %%
# Load the dataset from the specified file path into a pandas DataFrame named data_frame.
file_path = "DataScienceSalaries.csv"
data_frame = pd.read_csv(file_path)
data_frame
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# # Write a python program to remove unnecessary columns i.e., salary and salary currency.

# %%
# removing salary and currency column temporary
update_df = data_frame.drop(['salary','salary_currency'],axis=1)
update_df
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# # Write a python program to remove the NaN missing values from updated dataframe.

# %%
# removing NaN values
update_df.dropna()
# Out:
#       work_year experience_level employment_type                 job_title  \
# 0          2023               SE              FT  Principal Data Scientist
# 1          2023               MI              CT               ML Engineer
# 2          2023               MI              CT               ML Engineer
# 3          2023               SE              FT            Data Scientist
# 4          2023               SE              FT            Data Scientist
# ...         ...              ...             ...                       ...
# 3750       2020               SE              FT            Data Scientist
# 3751       2021               MI              FT  Principal Data Scientist
# 3752       2020               EN              FT            Data Scientist
# 3753       2020               EN              CT     Business Data Analyst
# 3754       2021               SE              FT      Data Science Manager
#
# ...

# %% [markdown]
# # Write a python program to check duplicates value in the dataframe.

# %%
#checking duplicate values in dataframe
check_duplicate = data_frame[data_frame.duplicated()]
check_duplicate
# Out:
#       work_year experience_level employment_type           job_title  salary  \
# 115        2023               SE              FT      Data Scientist  150000
# 123        2023               SE              FT  Analytics Engineer  289800
# 153        2023               MI              FT       Data Engineer  100000
# 154        2023               MI              FT       Data Engineer   70000
# 160        2023               SE              FT       Data Engineer  115000
# ...         ...              ...             ...                 ...     ...
# 3439       2022               MI              FT      Data Scientist   78000
# 3440       2022               SE              FT       Data Engineer  135000
# 3441       2022               SE              FT       Data Engineer  115000
# 3586       2021               MI              FT       Data Engineer  200000
# 3709       2021               MI              FT      Data Scientist   76760
#
# ...

# %% [markdown]
# # Write a python program to see the unique values from all the columns in the dataframe.

# %%
# see the unique values from all columns
data_frame.apply(lambda x: x.unique())
# Out:
# work_year                                      [2023, 2022, 2020, 2021]
# experience_level                                       [SE, MI, EN, EX]
# employment_type                                        [FT, CT, FL, PT]
# job_title             [Principal Data Scientist, ML Engineer, Data S...
# salary                [80000, 30000, 25500, 175000, 120000, 222200, ...
# salary_currency       [EUR, USD, INR, HKD, CHF, GBP, AUD, SGD, CAD, ...
# salary_in_usd         [85847, 30000, 25500, 175000, 120000, 222200, ...
# employee_residence    [ES, US, CA, DE, GB, NG, IN, HK, PT, NL, CH, C...
# remote_ratio                                               [100, 0, 50]
# company_location      [ES, US, CA, DE, GB, NG, IN, HK, NL, CH, CF, F...
# company_size                                                  [L, S, M]
# dtype: object

# %% [markdown]
# ## Rename the experience level columns as below
# #### SE – Senior Level/Expert
# #### MI – Medium Level/Intermediate
# #### EN – Entry Level
# #### EX – Executive Level

# %%
# creating dictionary
rename = {
    'SE': 'Senior Level/Expert',
    'MI': 'Medium Level/Intermediate',
    'EN': 'Entry Level',
    'EX': 'Executive Level'
}
# rename the experience levels values in the data frame using the rename dictionary

data_frame['experience_level'] = data_frame['experience_level'].replace(rename)
data_frame
# Out:
#       work_year           experience_level employment_type  \
# 0          2023        Senior Level/Expert              FT
# 1          2023  Medium Level/Intermediate              CT
# 2          2023  Medium Level/Intermediate              CT
# 3          2023        Senior Level/Expert              FT
# 4          2023        Senior Level/Expert              FT
# ...         ...                        ...             ...
# 3750       2020        Senior Level/Expert              FT
# 3751       2021  Medium Level/Intermediate              FT
# 3752       2020                Entry Level              FT
# 3753       2020                Entry Level              CT
# 3754       2021        Senior Level/Expert              FT
#
#                      job_title   salary salary_currency  salary_in_usd  \
# 0     Principal Data Scientist    80000             EUR          85847
# 1                  ML Engineer    30000             USD          30000
# ...

# %% [markdown]
# ## Write a Python program to show summary statistics of sum, mean, standard deviation, skewness, and kurtosis of any chosen variable.

# %%
# Generate a summary statistics for the 'salary' column in the data frame
summry = data_frame['salary'].describe()
print('Summry: \n', summry)
# Out:
# Summry:
#  count    3.755000e+03
# mean     1.906956e+05
# std      6.716765e+05
# min      6.000000e+03
# 25%      1.000000e+05
# 50%      1.380000e+05
# 75%      1.800000e+05
# max      3.040000e+07
# Name: salary, dtype: float64

# %% [markdown]
# # Write a python program to sum of any choosen variable

# %%
# Calculate the sum of the 'salary' column in the data frame
sum = data_frame['salary'].sum()
sum
# Out:
# 716061872

# %% [markdown]
# # Write a python program to mean of any choosen variable

# %%
# Calculate the mean of the 'salary' column in the data frame
mean = data_frame['salary'].mean()
mean
# Out:
# 190695.57177097205

# %% [markdown]
# # Write a python program to standard deviation of any choosen variable

# %%
# Calculate the sum of the 'standard deviation' column in the data frame
standard_deviation = data_frame['salary'].std()
standard_deviation
# Out:
# 671676.5005079071

# %% [markdown]
# # Write a python program to skewness of any choosen variable

# %%
# Calculate the sekwness of the 'salary' column in the data frame
skewness = data_frame['salary'].skew()
skewness
# Out:
# 28.937932169111605

# %% [markdown]
# # Write a python program to kurtosis of any choosed variable

# %%
# Calculate the kurtosis of the 'salary' column in the data frame
kurtosis = data_frame['salary'].kurtosis()
kurtosis
# Out:
# 1147.5673898192115

# %% [markdown]
# # Write a Python program to calculate and show correlation of all variables

# %%
# Calculate the correlation of all variables in the data frame
calculate_correlation = data_frame.corr(numeric_only = True)
calculate_correlation
# Out:
#                work_year    salary  salary_in_usd  remote_ratio
# work_year       1.000000 -0.094724       0.228290     -0.236430
# salary         -0.094724  1.000000      -0.023676      0.028731
# salary_in_usd   0.228290 -0.023676       1.000000     -0.064171
# remote_ratio   -0.236430  0.028731      -0.064171      1.000000

# %% [markdown]
# # Data Exploration

# %% [markdown]
# # Write a python program to find out top 15 jobs. Make a bar graph of salary as well.

# %%
# Grouping job_title, calculating mean of salary, and sorting it in descending order, and then selecting the top 15 jobs
top_jobs = data_frame['job_title'].value_counts().head(15).index
fifteen_job_title = data_frame[data_frame['job_title'].isin(top_jobs)]
mean_salary = fifteen_job_title.groupby('job_title')['salary'].mean().reset_index()
job_sorted = mean_salary.sort_values(by='salary', ascending=False)

# Create a figure with a specific size
plt.figure(figsize=(12, 8))

# Plotting a bar chart for the top 15 job titles and their average salaries
plt.bar(job_sorted['job_title'], job_sorted['salary'], width=0.4, color='skyblue')

# Setting labels and title for the plot
plt.xlabel('Job Title')
plt.ylabel('Salary')
plt.title('Top 15 Jobs')

# Rotating the x-axis labels for better visibility
plt.xticks(rotation=90, ha='right')

# Adjusting layout and displaying the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# # Which job has the highest salaries? Illustrate with bar graph.

# %%
# Calculating the highest salaries among different job titles in the data frame.
highest_salaries = data_frame.groupby('job_title')['salary'].sum()
highest_salaries.max()
# Out:
# 200821720

# %%
plt.figure(figsize=(30, 12))
# Create a bar chart with job titles on the x-axis and corresponding salaries on the y-axis
plt.bar(highest_salaries.index, highest_salaries.values, width=1, color='skyblue')

# Seting labels for x and y axes
plt.xlabel('Job Title')
plt.ylabel('Salary')

# Set the title of the plot
plt.title('Highest Salaries by Job Title')

# Rotate x-axis labels 
plt.xticks(rotation=90, ha='right')

# Adjust subplot parameters for a tight layout
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # Write a python program to find out salaries based on experience level. Illustrate it through bar graph.

# %%
# Calculate the total salary for each experience level by grouping the data frame
Salary_experience = data_frame.groupby('experience_level')['salary'].sum()
Salary_experience
# Out:
# experience_level
# Entry Level                   60281977
# Executive Level               28135451
# Medium Level/Intermediate    199801247
# Senior Level/Expert          427843197
# Name: salary, dtype: int64

# %%
plt.figure(figsize=(8, 5))
# Create a bar chart with experience levels on the x-axis and corresponding salaries on the y-axis
plt.bar(Salary_experience.index, Salary_experience.values, color='skyblue', width=0.4)

# Set labels for x and y axes
plt.xlabel('Experience Level')
plt.ylabel('Salary')

# Set the title of the plot
plt.title('Salary Based on Experience Level')

# Add a horizontal grid with dashed lines
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust subplot parameters for a tight layout
plt.tight_layout()

# Display the plot
plt.show()

# %% [markdown]
# # Write a Python program to show histogram and box plot of any chosen different variables. Use proper labels in the graph.

# %%
import matplotlib.pyplot as plt

# Set the figure size for the plots
plt.figure(figsize=(15, 6))

# Create a subplot for the histogram
plt.subplot(1, 2, 1)
# Plot the histogram of the 'salary_in_usd' column from the data frame
data_frame['salary_in_usd'].hist()
# Set the title and axis labels for the histogram
plt.title('Histogram of Salary (USD)')
plt.xlabel('Salary (USD)')
plt.ylabel('Frequency')

# Create a subplot for the box plot
plt.subplot(1, 2, 2)
# Plot the box plot of the 'salary_in_usd' column from the data frame
data_frame.boxplot(column='salary_in_usd')
# Set the title and axis labels for the box plot
plt.title('Salary Box Plot')
plt.ylabel('Salary (USD)')

# Display the plots
plt.show()
